# %%
import json
import pandas as pd

# %%
path = 'data\log.json'

with open('data\log.json','r') as f:
    data = json.load(f)

# Flattening JSON data
df = pd.json_normalize(data)

# %%
df.head(20)
# Out:
#    MessageType MessageVerb  Sequential  Ranges  \
# 0        Event        Shot        True      12
# 1        Event        Shot        True      10
# 2        Event        Shot        True      12
# 3        Event        Shot        True      10
# 4        Event        Shot        True      12
# 5        Event        Shot        True      12
# 6        Event        Shot        True      10
# 7        Event        Shot        True      12
# 8        Event        Shot        True      12
# 9        Event        Shot        True       8
# 10       Event        Shot        True      10
# 11       Event        Shot        True      12
# 12       Event        Shot        True      10
# 13       Event        Shot        True      12
# 14       Event        Shot        True       8
#
#                                               Objects  \
# 0   [{'ShotDateTime': '2022-06-15 18:28:12.000', '...
# 1   [{'ShotDateTime': '2022-06-15 18:28:14.000', '...
# ...
