# %%
import json
import pandas as pd

# %%
path = 'data\log.json'

# %%
with open(path,'r') as f:
    data = json.load(f)

# Flattening JSON data
df = pd.json_normalize(data, record_path=['Objects'])

# %%
df.head(20)
# Out:
#                ShotDateTime TLStatus  LastTLChange      Source  Range  \
# 0   2022-06-15 18:28:12.000    green        481295  OpticScore     12
# 1   2022-06-15 18:28:14.000    green        102789  OpticScore     10
# 2   2022-06-15 18:28:24.000    green        492713  OpticScore     12
# 3   2022-06-15 18:28:43.000    green        131772  OpticScore     10
# 4   2022-06-15 18:28:46.000    green        515267  OpticScore     12
# 5   2022-06-15 18:28:59.000    green        528265  OpticScore     12
# 6   2022-06-15 18:29:04.000    green        152715  OpticScore     10
# 7   2022-06-15 18:29:12.000    green        541076  OpticScore     12
# 8   2022-06-15 18:29:24.000    green        553215  OpticScore     12
# 9   2022-06-15 18:29:27.000    green         40210  OpticScore      8
# 10  2022-06-15 18:29:28.000    green        177499  OpticScore     10
# 11  2022-06-15 18:29:38.000    green        567331  OpticScore     12
# 12  2022-06-15 18:29:49.000    green        197897  OpticScore     10
# 13  2022-06-15 18:29:51.000    green        579718  OpticScore     12
# 14  2022-06-15 18:29:55.000    green         68606  OpticScore      8
#
#     Shooter Competition DiscType DiscTypeRaw     X  ...  \
# 0       NaN        None       LG        None  -748  ...
# 1       NaN        None       LG        None -1584  ...
# 2       NaN        None       LG        None -3324  ...
# 3       NaN        None       LG        None  -617  ...
# 4       NaN        None       LG        None  -238  ...
# 5       NaN        None       LG        None -1488  ...
# 6       NaN        None       LG        None  -440  ...
# 7       NaN        None       LG        None  -331  ...
# 8       NaN        None       LG        None  -480  ...
# 9       NaN        None      LGA        None   452  ...
# 10      NaN        None       LG        None   -78  ...
# 11      NaN        None       LG        None  2601  ...
# 12      NaN        None       LG        None   126  ...
# 13      NaN        None       LG        None -1639  ...
# 14      NaN        None      LGA        None   650  ...
#
#                 MenuItem.MenuPointName  MenuItem.MenuItemName  \
# 0                             Training      LP 59,5 (rund, 2)
# 1                           Luftgewehr              40 Schuss
# 2                             Training      LP 59,5 (rund, 2)
# 3                           Luftgewehr              40 Schuss
# 4                             Training      LP 59,5 (rund, 2)
# 5                             Training      LP 59,5 (rund, 2)
# 6                           Luftgewehr              40 Schuss
# 7                             Training      LP 59,5 (rund, 2)
# 8                             Training      LP 59,5 (rund, 2)
# 9   LGA 1. grï¿½ne Eichel 70 Ringe LGA                   None
# 10                          Luftgewehr              40 Schuss
# 11                            Training      LP 59,5 (rund, 2)
# 12                          Luftgewehr              40 Schuss
# 13                            Training      LP 59,5 (rund, 2)
# 14  LGA 1. grï¿½ne Eichel 70 Ringe LGA                   None
#
#                            MenuItem.UUID  Shooter.Firstname  Shooter.Lastname  \
# 0   E29A4DC1-2487-45E8-9995-8EFFDE65239E                NaN               NaN
# 1   A0D23232-255E-44F9-93BD-27DEA3CA7F39                NaN               NaN
# 2   4CCAB791-A27A-4EEA-95BD-A45CCFCC7DFE                NaN               NaN
# 3   4075443B-67F2-4374-8A37-204579B5EAFC                NaN               NaN
# 4   5BE06836-A7DC-43C8-902F-05298FD7A5E0                NaN               NaN
# 5   267C7D58-C76E-45A3-8774-E0BAF7C10F1D                NaN               NaN
# 6   0B3EC0A4-F89D-47E2-A1A8-DA44DF7B4115                NaN               NaN
# 7   E2B11A58-DF88-493C-A9F2-45DA1D47D88C                NaN               NaN
# 8   D8CC01A8-4445-4BB5-98FF-2255FB02BFD7                NaN               NaN
# 9   3D56769F-763F-4F0B-9B1E-0AEFDDF69118            Nicolas            Dissel
# 10  FF012440-B932-4BC8-AC1D-6DB9C3338595                NaN               NaN
# 11  B0BC374D-D92D-4682-8EF4-CD6CA8898478                NaN               NaN
# 12  9F286585-4971-4A3B-956C-DD50070EE18E                NaN               NaN
# 13  0CB76F99-E1C5-49FF-92DA-8789198ED5E7                NaN               NaN
# 14  7C102AA1-A859-40E7-ADA1-17C5F33B3C5D            Nicolas            Dissel
#
#     Shooter.Birthyear  Shooter.InternalID  Shooter.Identification  \
# 0                 NaN                 NaN                     NaN
# 1                 NaN                 NaN                     NaN
# 2                 NaN                 NaN                     NaN
# 3                 NaN                 NaN                     NaN
# 4                 NaN                 NaN                     NaN
# 5                 NaN                 NaN                     NaN
# 6                 NaN                 NaN                     NaN
# 7                 NaN                 NaN                     NaN
# 8                 NaN                 NaN                     NaN
# 9              2011.0                                         308
# 10                NaN                 NaN                     NaN
# 11                NaN                 NaN                     NaN
# 12                NaN                 NaN                     NaN
# 13                NaN                 NaN                     NaN
# 14             2011.0                                         308
#
#     Shooter.Team  Shooter.Club
# 0            NaN           NaN
# 1            NaN           NaN
# 2            NaN           NaN
# 3            NaN           NaN
# 4            NaN           NaN
# 5            NaN           NaN
# 6            NaN           NaN
# 7            NaN           NaN
# 8            NaN           NaN
# 9            NaN           NaN
# 10           NaN           NaN
# 11           NaN           NaN
# 12           NaN           NaN
# 13           NaN           NaN
# 14           NaN           NaN
#
# [15 rows x 35 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 35 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ShotDateTime            15 non-null     object
#  1   TLStatus                15 non-null     object
#  2   LastTLChange            15 non-null     int64
#  3   Source                  15 non-null     object
#  4   Range                   15 non-null     int64
#  5   Shooter                 0 non-null      float64
#  6   Competition             0 non-null      object
#  7   DiscType                15 non-null     object
#  8   DiscTypeRaw             0 non-null      object
#  9   X                       15 non-null     int64
#  10  Y                       15 non-null     int64
#  11  Distance                15 non-null     float64
#  12  Count                   15 non-null     int64
#  13  FullValue               15 non-null     int64
#  14  DecValue                15 non-null     float64
#  15  Run                     15 non-null     int64
#  16  IsValid                 15 non-null     bool
#  17  IsWarmup                15 non-null     bool
#  18  IsHot                   15 non-null     bool
#  19  IsDummy                 15 non-null     bool
#  20  IsInnerten              15 non-null     bool
#  21  IsShootoff              15 non-null     bool
#  22  Remark                  15 non-null     object
#  23  UUID                    15 non-null     object
#  24  MenuItem.MenuID         15 non-null     object
#  25  MenuItem.MenuPointName  15 non-null     object
#  26  MenuItem.MenuItemName   13 non-null     object
#  27  MenuItem.UUID           15 non-null     object
#  28  Shooter.Firstname       2 non-null      object
#  29  Shooter.Lastname        2 non-null      object
#  30  Shooter.Birthyear       2 non-null      float64
#  31  Shooter.InternalID      2 non-null      object
#  32  Shooter.Identification  2 non-null      object
#  33  Shooter.Team            0 non-null      float64
#  34  Shooter.Club            0 non-null      float64
# dtypes: bool(6), float64(6), int64(7), object(16)
# memory usage: 3.6+ KB

# %% [markdown]
# Log File Zeile für Zeile auslesen, json/dictionary Element auslesen und in pandas Element umwandeln.

# %%
log_path = 'data/OUT-JSONInterface.log'
path = 'data/oldiepokal.log'
shots = pd.DataFrame()

# %%
with open(log_path) as log:
    for line in log:
        element = pd.json_normalize(json.loads(line), record_path=['Objects'])
        if len(element.columns) > 32:
            element.drop(element.columns[[1,2,3,7,8,9,18,19,20,21,22,26,32,33]], axis=1, inplace=True)
            shots = pd.concat([shots, element], axis=0, ignore_index=True)

shots.head()
# Out:
#               ShotDateTime  Range Competition DiscType  Distance  Count  \
# 0  2022-06-15 18:29:27.000      8        None      LGA     463.1      0
# 1  2022-06-15 18:29:55.000      8        None      LGA     661.9      1
# 2  2022-06-15 18:30:14.000      8        None      LGA     759.1      2
# 3  2022-06-15 18:30:51.000      8        None      LGA     448.8      3
# 4  2022-06-15 18:31:09.000      8        None      LGA     347.8      4
#
#    FullValue  DecValue  Run  IsValid  IsWarmup  IsHot Shooter.Firstname  \
# 0          9       9.1    2     True     False   True           Nicolas
# 1          8       8.3    2     True     False   True           Nicolas
# 2          7       7.9    2     True     False   True           Nicolas
# 3          9       9.2    2     True     False   True           Nicolas
# 4          9       9.6    2     True     False   True           Nicolas
#
#   Shooter.Lastname  Shooter.Birthyear Shooter.Identification Shooter.Team  \
# 0           Dissel               2011                    308         None
# 1           Dissel               2011                    308         None
# 2           Dissel               2011                    308         None
# 3           Dissel               2011                    308         None
# 4           Dissel               2011                    308         None
#
#   Shooter.Club MenuItem.MenuID            MenuItem.MenuPointName
# 0         None  1000_100060012  LGA 1. grüne Eichel 70 Ringe LGA
# 1         None  1000_100060012  LGA 1. grüne Eichel 70 Ringe LGA
# 2         None  1000_100060012  LGA 1. grüne Eichel 70 Ringe LGA
# 3         None  1000_100060012  LGA 1. grüne Eichel 70 Ringe LGA
# 4         None  1000_100060012  LGA 1. grüne Eichel 70 Ringe LGA

# %%
shots
# Out:
#                ShotDateTime  Range Competition DiscType  Distance  Count  \
# 0   2022-06-15 18:29:27.000      8        None      LGA     463.1      0
# 1   2022-06-15 18:29:55.000      8        None      LGA     661.9      1
# 2   2022-06-15 18:30:14.000      8        None      LGA     759.1      2
# 3   2022-06-15 18:30:51.000      8        None      LGA     448.8      3
# 4   2022-06-15 18:31:09.000      8        None      LGA     347.8      4
# ..                      ...    ...         ...      ...       ...    ...
# 72  2022-07-12 18:54:39.000      1        None      KKA     509.9      5
# 73  2022-07-12 18:55:03.000      1        None      KKA     656.4      6
# 74  2022-07-12 18:55:26.000      1        None      KKA    1924.2      7
# 75  2022-07-12 18:56:01.000      1        None      KKA    1627.0      8
# 76  2022-07-12 18:56:25.000      1        None      KKA    1560.8      9
#
#     FullValue  DecValue  Run  IsValid  IsWarmup  IsHot Shooter.Firstname  \
# 0           9       9.1    2     True     False   True           Nicolas
# 1           8       8.3    2     True     False   True           Nicolas
# 2           7       7.9    2     True     False   True           Nicolas
# 3           9       9.2    2     True     False   True           Nicolas
# 4           9       9.6    2     True     False   True           Nicolas
# ..        ...       ...  ...      ...       ...    ...               ...
# 72         10      10.3    2     True     False   True            Regina
# 73         10      10.1    2     True     False   True            Regina
# 74          8       8.5    2     True     False   True            Regina
# 75          8       8.9    2     True     False   True            Regina
# 76          9       9.0    2     True     False   True            Regina
#
#    Shooter.Lastname  Shooter.Birthyear Shooter.Identification Shooter.Team  \
# 0            Dissel               2011                    308         None
# 1            Dissel               2011                    308         None
# 2            Dissel               2011                    308         None
# 3            Dissel               2011                    308         None
# 4            Dissel               2011                    308         None
# ..              ...                ...                    ...          ...
# 72     306- Neumann               1956                    306         None
# 73     306- Neumann               1956                    306         None
# 74     306- Neumann               1956                    306         None
# 75     306- Neumann               1956                    306         None
# 76     306- Neumann               1956                    306         None
#
#    Shooter.Club MenuItem.MenuID            MenuItem.MenuPointName
# 0          None  1000_100060012  LGA 1. grüne Eichel 70 Ringe LGA
# 1          None  1000_100060012  LGA 1. grüne Eichel 70 Ringe LGA
# 2          None  1000_100060012  LGA 1. grüne Eichel 70 Ringe LGA
# 3          None  1000_100060012  LGA 1. grüne Eichel 70 Ringe LGA
# 4          None  1000_100060012  LGA 1. grüne Eichel 70 Ringe LGA
# ..          ...             ...                               ...
# 72         None  1000_100090012  KKA 1. grüne Eichel 70 Ringe KKA
# 73         None  1000_100090012  KKA 1. grüne Eichel 70 Ringe KKA
# 74         None  1000_100090012  KKA 1. grüne Eichel 70 Ringe KKA
# 75         None  1000_100090012  KKA 1. grüne Eichel 70 Ringe KKA
# 76         None  1000_100090012  KKA 1. grüne Eichel 70 Ringe KKA
#
# [77 rows x 20 columns]

# %%
type(shots['ShotDateTime'].max())
# Out:
# str

# %%
shots['MenuItem.MenuPointName'].unique()
# Out:
# array(['LGA 1. grüne Eichel 70 Ringe LGA',
#        'KKA silberne Schnur 85 Ringe KKA', 'KKA Preisschießen KKA',
#        'KKA Jubiläumspokal  KKA', 'KKA 1. grüne Eichel 70 Ringe KKA'],
#       dtype=object)

# %%
shots['MenuItem.MenuID'].unique()
# Out:
# array(['1000_100060012', '1000_100090016', '1000_00100090001',
#        '1000_00100090002', '1000_100090012'], dtype=object)

# %%
PreisKKA = shots[shots['MenuItem.MenuPointName'] == 'KKA Preisschießen KKA']
Pokal = shots[shots['MenuItem.MenuPointName'] == 'KKA Jubiläumspokal  KKA']

# %%
PreisKKA
# Out:
#                ShotDateTime  Range Competition DiscType  Distance  Count  \
# 45  2022-06-27 17:37:22.000      1        None      KKA    2492.6      1
# 46  2022-06-27 17:37:23.000      1        None      KKA    2260.6      2
# 47  2022-06-27 17:37:34.000      1        None      KKA    1823.9      3
# 55  2022-06-27 17:42:03.000      1        None      KKA    2102.9      1
# 56  2022-06-27 17:42:04.000      1        None      KKA    1314.9      2
# 57  2022-06-27 17:42:04.000      1        None      KKA    2606.4      3
# 58  2022-06-27 17:42:05.000      1        None      KKA    1430.8      4
# 59  2022-06-27 17:42:05.000      1        None      KKA    1427.3      5
# 60  2022-06-27 17:42:06.000      1        None      KKA    2237.6      6
# 61  2022-06-27 17:42:06.000      1        None      KKA    1255.9      7
# 62  2022-06-27 17:42:08.000      1        None      KKA    2703.0      8
# 63  2022-06-27 17:42:09.000      1        None      KKA     862.3      9
# 64  2022-06-27 17:42:09.000      1        None      KKA    1570.0     10
# 65  2022-06-27 17:42:09.000      1        None      KKA    1514.4     11
#
#     FullValue  DecValue  Run  IsValid  IsWarmup  IsHot Shooter.Firstname  \
# 45          7       7.8    2     True     False   True              Toni
# 46          8       8.1    2     True     False   True              Toni
# 47          8       8.7    2     True     False  False              Toni
# 55          8       8.3    2     True     False   True               Han
# 56          9       9.3    2     True     False   True               Han
# 57          7       7.7    2     True     False   True               Han
# 58          9       9.2    2     True     False   True               Han
# 59          9       9.2    2     True     False   True               Han
# 60          8       8.2    2     True     False   True               Han
# 61          9       9.4    2     True     False   True               Han
# 62          7       7.6    2     True     False   True               Han
# 63          9       9.9    2     True     False   True               Han
# 64          9       9.0    2     True     False   True               Han
# 65          9       9.1    2     True     False  False               Han
#
#    Shooter.Lastname  Shooter.Birthyear Shooter.Identification Shooter.Team  \
# 45             Test               1980                      1         None
# 46             Test               1980                      1         None
# 47             Test               1980                      1         None
# 55             Solo               1980                      2         None
# 56             Solo               1980                      2         None
# 57             Solo               1980                      2         None
# 58             Solo               1980                      2         None
# 59             Solo               1980                      2         None
# 60             Solo               1980                      2         None
# 61             Solo               1980                      2         None
# 62             Solo               1980                      2         None
# 63             Solo               1980                      2         None
# 64             Solo               1980                      2         None
# 65             Solo               1980                      2         None
#
#    Shooter.Club   MenuItem.MenuID MenuItem.MenuPointName
# 45         None  1000_00100090001  KKA Preisschießen KKA
# 46         None  1000_00100090001  KKA Preisschießen KKA
# 47         None  1000_00100090001  KKA Preisschießen KKA
# 55         None  1000_00100090001  KKA Preisschießen KKA
# 56         None  1000_00100090001  KKA Preisschießen KKA
# 57         None  1000_00100090001  KKA Preisschießen KKA
# 58         None  1000_00100090001  KKA Preisschießen KKA
# 59         None  1000_00100090001  KKA Preisschießen KKA
# 60         None  1000_00100090001  KKA Preisschießen KKA
# 61         None  1000_00100090001  KKA Preisschießen KKA
# 62         None  1000_00100090001  KKA Preisschießen KKA
# 63         None  1000_00100090001  KKA Preisschießen KKA
# 64         None  1000_00100090001  KKA Preisschießen KKA
# 65         None  1000_00100090001  KKA Preisschießen KKA

# %%
Pokal
# Out:
#                ShotDateTime  Range Competition DiscType  Distance  Count  \
# 48  2022-06-27 17:38:53.000      1        None      KKA    2273.7      1
# 49  2022-06-27 17:38:55.000      1        None      KKA    1515.6      2
# 50  2022-06-27 17:38:56.000      1        None      KKA    2140.6      3
# 51  2022-06-27 17:38:56.000      1        None      KKA    2347.1      4
# 52  2022-06-27 17:38:56.000      1        None      KKA    3270.6      5
# 53  2022-06-27 17:38:57.000      1        None      KKA    3662.4      6
# 54  2022-06-27 17:38:58.000      1        None      KKA    2017.9      6
#
#     FullValue  DecValue  Run  IsValid  IsWarmup  IsHot Shooter.Firstname  \
# 48          8       8.1    2     True     False   True              Toni
# 49          9       9.1    2     True     False   True              Toni
# 50          8       8.3    2     True     False   True              Toni
# 51          8       8.0    2     True     False   True              Toni
# 52          6       6.9    2     True     False   True              Toni
# 53          6       6.4    2     True     False  False              Toni
# 54          8       8.4    2     True     False  False              Toni
#
#    Shooter.Lastname  Shooter.Birthyear Shooter.Identification Shooter.Team  \
# 48             Test               1980                      1         None
# 49             Test               1980                      1         None
# 50             Test               1980                      1         None
# 51             Test               1980                      1         None
# 52             Test               1980                      1         None
# 53             Test               1980                      1         None
# 54             Test               1980                      1         None
#
#    Shooter.Club   MenuItem.MenuID   MenuItem.MenuPointName
# 48         None  1000_00100090002  KKA Jubiläumspokal  KKA
# 49         None  1000_00100090002  KKA Jubiläumspokal  KKA
# 50         None  1000_00100090002  KKA Jubiläumspokal  KKA
# 51         None  1000_00100090002  KKA Jubiläumspokal  KKA
# 52         None  1000_00100090002  KKA Jubiläumspokal  KKA
# 53         None  1000_00100090002  KKA Jubiläumspokal  KKA
# 54         None  1000_00100090002  KKA Jubiläumspokal  KKA

# %% [markdown]
# # Preisschießen-Routine
#
# Es gewinnt die Person mit den besten zwei 10en (bei Gleichstand zählt geringster Teiler).
#
# Nachsetzen ist erlaubt

# %% [markdown]
# # Pokalschießen-Routine
#
# Manschaften mit 4 (Männer) oder 3 (Frauen, Jugend) Personen. Jede Person 5 Schuss, Team mit bester Gesamtsumme gewinnt

# %% [markdown]
# # Bestmann-Routine
#
# Person mit bester 10 bei kleinstem Teiler gewinnt.
#
# Jeweils für KK und LG ?

# %%
KKshooters = shots[shots['DiscType'] == 'KKA']['Shooter.Identification'].unique()
KKshots = shots[shots['DiscType'] == 'KKA']
LGshooters = shots[shots['DiscType'] == 'LGA']['Shooter.Identification'].unique()
LGshots = shots[shots['DiscType'] == 'LGA']

# %%
KKshooters
# Out:
# array(['245', '1', '2', '306'], dtype=object)

# %%
LGshooters
# Out:
# array(['308', '217'], dtype=object)

# %% [markdown]
# ## KK-Bestmann

# %%
KKbest = pd.DataFrame()

for shooter in KKshooters:
    df = KKshots[KKshots['Shooter.Identification'] == shooter]
    max = df.loc[df['DecValue'].idxmax()]
    KKbest = pd.concat([KKbest, max.to_frame().transpose()], axis=0, ignore_index=True)

KKbest.sort_values(['DecValue', 'Distance','ShotDateTime'], ascending=[False,True,True], inplace=True)
KKbest.reset_index(inplace=True)
KKbest

#TODO nur IsHot Schüsse ?
# Out:
#    index             ShotDateTime Range Competition DiscType Distance Count  \
# 0      0  2022-06-21 18:27:01.000     4        None      KKA    307.3     0
# 1      3  2022-07-12 18:54:39.000     1        None      KKA    509.9     5
# 2      2  2022-06-27 17:42:09.000     1        None      KKA    862.3     9
# 3      1  2022-06-27 17:38:55.000     1        None      KKA   1515.6     2
#
#   FullValue DecValue Run  ... IsWarmup  IsHot Shooter.Firstname  \
# 0        10     10.6   1  ...     True  False          Krystian
# 1        10     10.3   2  ...    False   True            Regina
# 2         9      9.9   2  ...    False   True               Han
# 3         9      9.1   2  ...    False   True              Toni
#
#   Shooter.Lastname Shooter.Birthyear Shooter.Identification Shooter.Team  \
# 0  245 Dechsheimer              1995                    245         None
# 1     306- Neumann              1956                    306         None
# 2             Solo              1980                      2         None
# 3             Test              1980                      1         None
#
#   Shooter.Club   MenuItem.MenuID            MenuItem.MenuPointName
# 0         None    1000_100090016  KKA silberne Schnur 85 Ringe KKA
# 1         None    1000_100090012  KKA 1. grüne Eichel 70 Ringe KKA
# 2         None  1000_00100090001             KKA Preisschießen KKA
# 3         None  1000_00100090002           KKA Jubiläumspokal  KKA
#
# [4 rows x 21 columns]

# %% [markdown]
# ### Transformation für Display
# Platzierung, Vorname, Nachname, ggf. Mitgliedsnummer, Punktzahl

# %%
display = KKbest[['Shooter.Firstname', 'Shooter.Lastname', 'Shooter.Identification', 'FullValue', 'Distance']]
display.index += 1
display
# Out:
#   Shooter.Firstname Shooter.Lastname Shooter.Identification FullValue Distance
# 1          Krystian  245 Dechsheimer                    245        10    307.3
# 2            Regina     306- Neumann                    306        10    509.9
# 3               Han             Solo                      2         9    862.3
# 4              Toni             Test                      1         9   1515.6

# %% [markdown]
# ## LG Bestmann

# %%
LGbest = pd.DataFrame()

for shooter in LGshooters:
    df = LGshots[LGshots['Shooter.Identification'] == shooter]
    max = df.loc[df['DecValue'].idxmax()]
    LGbest = pd.concat([LGbest, max.to_frame().transpose()], axis=0, ignore_index=True)

LGbest.sort_values(['DecValue', 'Distance'], ascending=[False,True], inplace=True)
LGbest.reset_index(inplace=True)
LGbest
# Out:
#    index             ShotDateTime Range Competition DiscType Distance Count  \
# 0      1  2022-06-15 18:45:47.000    14        None      LGA    128.1     6
# 1      0  2022-06-15 18:32:50.000     8        None      LGA    157.4     7
#
#   FullValue DecValue Run  ... IsWarmup  IsHot Shooter.Firstname  \
# 0        10     10.4   1  ...     True  False           Melissa
# 1        10     10.3   2  ...    False   True           Nicolas
#
#   Shooter.Lastname Shooter.Birthyear Shooter.Identification Shooter.Team  \
# 0   217 Eggerstedt              2013                    217         None
# 1           Dissel              2011                    308         None
#
#   Shooter.Club MenuItem.MenuID            MenuItem.MenuPointName
# 0         None  1000_100060012  LGA 1. grüne Eichel 70 Ringe LGA
# 1         None  1000_100060012  LGA 1. grüne Eichel 70 Ringe LGA
#
# [2 rows x 21 columns]

# %%
display = LGbest[['Shooter.Firstname', 'Shooter.Lastname', 'Shooter.Identification', 'FullValue', 'Distance']]
display.index += 1
display
# Out:
#   Shooter.Firstname Shooter.Lastname Shooter.Identification FullValue Distance
# 1           Melissa   217 Eggerstedt                    217        10    128.1
# 2           Nicolas           Dissel                    308        10    157.4

# %% [markdown]
# ## Test of Backend-Functions

# %%
import backendfunctions as bf

oldiepath = 'data\oldiepokal.log'

# %%
#oldies_full = bf.read_logfile(oldiepath)
#oldies_full.head()

# %%
oldies_full = bf.read_logfile2(oldiepath)
oldies_full.head()
# Out:
#               ShotDateTime Competition DiscType  Distance  Count  FullValue  \
# 0  2022-06-15 18:29:27.000        None      LGA     463.1      0          9
# 1  2022-06-15 18:29:55.000        None      LGA     661.9      1          8
# 2  2022-06-15 18:30:14.000        None      LGA     759.1      2          7
# 3  2022-06-15 18:30:51.000        None      LGA     448.8      3          9
# 4  2022-06-15 18:31:09.000        None      LGA     347.8      4          9
#
#    DecValue  IsHot Shooter.Firstname Shooter.Lastname  Shooter.Birthyear  \
# 0       9.1   True           Nicolas           Dissel               2011
# 1       8.3   True           Nicolas           Dissel               2011
# 2       7.9   True           Nicolas           Dissel               2011
# 3       9.2   True           Nicolas           Dissel               2011
# 4       9.6   True           Nicolas           Dissel               2011
#
#   Shooter.Identification Shooter.Team Shooter.Club  \
# 0                    308         None         None
# 1                    308         None         None
# 2                    308         None         None
# 3                    308         None         None
# 4                    308         None         None
#
#             MenuItem.MenuPointName
# 0  LGA 1. grne Eichel 70 Ringe LGA
# 1  LGA 1. grne Eichel 70 Ringe LGA
# 2  LGA 1. grne Eichel 70 Ringe LGA
# 3  LGA 1. grne Eichel 70 Ringe LGA
# 4  LGA 1. grne Eichel 70 Ringe LGA

# %%
#oldies_full.info()

# %%
oldies_full['MenuItem.MenuPointName'].unique()
# Out:
# array(['LGA 1. grne Eichel 70 Ringe LGA',
#        'KKA silberne Schnur 85 Ringe KKA', 'KKA Preisschieen KKA',
#        'KKA Jubilumspokal  KKA', 'KKA 1. grne Eichel 70 Ringe KKA',
#        'KKA grne Schnur 65 Ringe KKA', 'LGA grne Schnur 65 Ringe LGA',
#        'KKA OldiPokal KKA', 'KKA Vogelteiler KKA', None], dtype=object)

# %%
best, oldies, u65 = bf.oldiepokal(oldies_full)

best.head()
# Out:
# c:\Users\kaisc\projects\Pokalschiessen\backendfunctions.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   max['TotalDistance'] = teiler
# c:\Users\kaisc\anaconda3\lib\site-packages\pandas\core\indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
#    Vorname       Nachname   id Scheiben Teiler
# 1   Marcel  321 Schlichte  322       10  220.9
# 2  Gerhard     040 Eilken   40       10  449.0
# 3    Bernd     008 Boysen    8       10  574.8
# 4  Steffen    187 Balhorn  187       10  740.2
# 5  Torsten    178 Damerow  178        9  826.6

# %%
oldies.head()
# Out:
#    index             ShotDateTime Competition DiscType Distance Count  \
# 0      9  2022-08-22 20:14:27.000        None      KKA    449.0     2
# 1      5  2022-08-22 20:01:48.000        None      KKA    574.8     2
# 2      4  2022-08-22 19:51:49.000        None      KKA   1024.0     1
# 3      7  2022-08-22 20:07:07.000        None      KKA   1145.3     2
# 4      8  2022-08-22 20:07:59.000        None      KKA   1720.0     2
#
#   FullValue DecValue IsHot Shooter.Firstname Shooter.Lastname  \
# 0        10     10.4  True           Gerhard       040 Eilken
# 1        10     10.2  True             Bernd       008 Boysen
# 2         9      9.7  True             Peter         111 Tamm
# 3         9      9.5  True         Christian        097 Meyer
# 4         8      8.8  True             Klaus        100 Meyer
#
#   Shooter.Birthyear Shooter.Identification Shooter.Team Shooter.Club  \
# 0              1952                     40         None         None
# 1              1949                      8         None         None
# 2              1955                    111         None         None
# 3              1939                     97         None         None
# 4              1947                    100         None         None
#
#   MenuItem.MenuPointName TotalDistance
# 0      KKA OldiPokal KKA        2098.2
# 1      KKA OldiPokal KKA        3106.6
# 2      KKA OldiPokal KKA        3591.6
# 3      KKA OldiPokal KKA        4141.3
# 4      KKA OldiPokal KKA        5042.8

# %%
u65.head()
# Out:
#    index             ShotDateTime Competition DiscType Distance Count  \
# 0      5  2022-08-22 19:40:56.000        None      KKA    220.9     1
# 1      7  2022-08-22 19:46:53.000        None      KKA   1047.3     0
# 2     10  2022-08-22 20:02:53.000        None      KKA   1102.3     2
# 3      6  2022-08-22 19:46:19.000        None      KKA   1165.6     1
# 4      9  2022-08-22 19:55:30.000        None      KKA   1468.0     1
#
#   FullValue DecValue IsHot Shooter.Firstname Shooter.Lastname  \
# 0        10     10.7  True            Marcel    321 Schlichte
# 1         9      9.6  True          Heinrich         161 Wbbe
# 2         9      9.6  True            Holger         137 Thne
# 3         9      9.5  True              Lars      185 Balhorn
# 4         9      9.1  True            Rudolf       248 Rieger
#
#   Shooter.Birthyear Shooter.Identification Shooter.Team Shooter.Club  \
# 0              1974                    322         None         None
# 1              1962                    161         None         None
# 2              1974                    137         None         None
# 3              1980                    185         None         None
# 4              1972                    248         None         None
#
#   MenuItem.MenuPointName TotalDistance
# 0      KKA OldiPokal KKA        1919.2
# 1      KKA OldiPokal KKA        2617.3
# 2      KKA OldiPokal KKA        2834.5
# 3      KKA OldiPokal KKA        3501.9
# 4      KKA OldiPokal KKA        3610.5

# %%
oldies_full[oldies_full['Shooter.Firstname'].isin(['Lars','Jan'])]
# Out:
#                 ShotDateTime Competition DiscType  Distance  Count  FullValue  \
# 101  2022-08-15 20:11:28.000        None      KKA    3014.4      0          7
# 102  2022-08-15 20:11:36.000        None      KKA     264.4      1         10
# 104  2022-08-15 20:13:50.000        None      KKA    4950.0      2          4
# 105  2022-08-15 20:16:58.000        None      KKA    1910.5      3          8
# 106  2022-08-15 20:18:02.000        None      KKA     678.7      4         10
# 111  2022-08-15 20:19:51.000        None      KKA    3475.5      5          6
# 112  2022-08-15 20:20:34.000        None      KKA    1453.0      6          9
# 116  2022-08-15 20:23:23.000        None      KKA    1757.2      7          8
# 119  2022-08-15 20:25:10.000        None      KKA     548.8      8         10
# 121  2022-08-15 20:26:58.000        None      KKA     367.0      9         10
# 168  2022-08-22 19:44:37.000        None      KKA    2007.4      0          8
# 171  2022-08-22 19:45:50.000        None      KKA    2847.4      0          7
# 173  2022-08-22 19:46:19.000        None      KKA    1165.6      1          9
# 174  2022-08-22 19:46:53.000        None      KKA    1510.9      2          9
# 240  2022-08-22 21:09:47.000        None      KKA    3524.2      0          6
# 241  2022-08-22 21:10:10.000        None      KKA    1302.4      1          9
# 242  2022-08-22 21:10:30.000        None      KKA    2907.9      2          7
# 243  2022-08-22 21:11:17.000        None      KKA    1484.6      0          9
#
#      DecValue  IsHot Shooter.Firstname Shooter.Lastname  Shooter.Birthyear  \
# 101       7.2   True              Lars       264 Rieger               2007
# 102      10.6   True              Lars       264 Rieger               2007
# 104       4.8   True              Lars       264 Rieger               2007
# 105       8.6   True              Lars       264 Rieger               2007
# 106      10.1   True              Lars       264 Rieger               2007
# 111       6.6   True              Lars       264 Rieger               2007
# 112       9.1   True              Lars       264 Rieger               2007
# 116       8.8   True              Lars       264 Rieger               2007
# 119      10.3   True              Lars       264 Rieger               2007
# 121      10.5   True              Lars       264 Rieger               2007
# 168       8.4   True              Lars      185 Balhorn               1980
# 171       7.4   True              Lars      185 Balhorn               1980
# 173       9.5   True              Lars      185 Balhorn               1980
# 174       9.1   True              Lars      185 Balhorn               1980
# 240       6.5   True               Jan         188 Host               1978
# 241       9.3   True               Jan         188 Host               1978
# 242       7.3   True               Jan         188 Host               1978
# 243       9.1   True               Jan         188 Host               1978
#
#     Shooter.Identification Shooter.Team Shooter.Club  \
# 101                    264         None         None
# 102                    264         None         None
# 104                    264         None         None
# 105                    264         None         None
# 106                    264         None         None
# 111                    264         None         None
# 112                    264         None         None
# 116                    264         None         None
# 119                    264         None         None
# 121                    264         None         None
# 168                    185         None         None
# 171                    185         None         None
# 173                    185         None         None
# 174                    185         None         None
# 240                    188         None         None
# 241                    188         None         None
# 242                    188         None         None
# 243                    188         None         None
#
#            MenuItem.MenuPointName
# 101  KKA grne Schnur 65 Ringe KKA
# 102  KKA grne Schnur 65 Ringe KKA
# 104  KKA grne Schnur 65 Ringe KKA
# 105  KKA grne Schnur 65 Ringe KKA
# 106  KKA grne Schnur 65 Ringe KKA
# 111  KKA grne Schnur 65 Ringe KKA
# 112  KKA grne Schnur 65 Ringe KKA
# 116  KKA grne Schnur 65 Ringe KKA
# 119  KKA grne Schnur 65 Ringe KKA
# 121  KKA grne Schnur 65 Ringe KKA
# 168           KKA Vogelteiler KKA
# 171             KKA OldiPokal KKA
# 173             KKA OldiPokal KKA
# 174             KKA OldiPokal KKA
# 240             KKA OldiPokal KKA
# 241             KKA OldiPokal KKA
# 242             KKA OldiPokal KKA
# 243           KKA Vogelteiler KKA

# %%
oldies_full[(oldies_full['Shooter.Firstname'] == 'Rudolf')]
# Out:
#                 ShotDateTime Competition DiscType  Distance  Count  FullValue  \
# 78   2022-08-15 20:03:00.000        None      KKA    2965.8      0          7
# 80   2022-08-15 20:03:26.000        None      KKA     700.3      1         10
# 82   2022-08-15 20:03:50.000        None      KKA     939.2      2          9
# 84   2022-08-15 20:04:15.000        None      KKA    1080.4      3          9
# 86   2022-08-15 20:04:41.000        None      KKA    1494.9      4          9
# 88   2022-08-15 20:05:14.000        None      KKA    1070.5      5          9
# 91   2022-08-15 20:05:41.000        None      KKA    3223.7      6          6
# 92   2022-08-15 20:06:02.000        None      KKA     987.5      7          9
# 94   2022-08-15 20:06:30.000        None      KKA     720.6      8         10
# 96   2022-08-15 20:07:00.000        None      KKA    2034.7      9          8
# 186  2022-08-22 19:55:02.000        None      KKA    2150.5      0          8
# 188  2022-08-22 19:55:30.000        None      KKA    1468.0      1          9
# 189  2022-08-22 19:56:22.000        None      KKA    2014.0      2          8
# 190  2022-08-22 19:57:38.000        None      KKA    2279.2      0          8
#
#      DecValue  IsHot Shooter.Firstname Shooter.Lastname  Shooter.Birthyear  \
# 78        7.2   True            Rudolf       248 Rieger               1972
# 80       10.1   True            Rudolf       248 Rieger               1972
# 82        9.8   True            Rudolf       248 Rieger               1972
# 84        9.6   True            Rudolf       248 Rieger               1972
# 86        9.1   True            Rudolf       248 Rieger               1972
# 88        9.6   True            Rudolf       248 Rieger               1972
# 91        6.9   True            Rudolf       248 Rieger               1972
# 92        9.7   True            Rudolf       248 Rieger               1972
# 94       10.1   True            Rudolf       248 Rieger               1972
# 96        8.4   True            Rudolf       248 Rieger               1972
# 186       8.3   True            Rudolf       248 Rieger               1972
# 188       9.1   True            Rudolf       248 Rieger               1972
# 189       8.4   True            Rudolf       248 Rieger               1972
# 190       8.1   True            Rudolf       248 Rieger               1972
#
#     Shooter.Identification Shooter.Team Shooter.Club  \
# 78                     248         None         None
# 80                     248         None         None
# 82                     248         None         None
# 84                     248         None         None
# 86                     248         None         None
# 88                     248         None         None
# 91                     248         None         None
# 92                     248         None         None
# 94                     248         None         None
# 96                     248         None         None
# 186                    248         None         None
# 188                    248         None         None
# 189                    248         None         None
# 190                    248         None         None
#
#               MenuItem.MenuPointName
# 78   KKA 1. grne Eichel 70 Ringe KKA
# 80   KKA 1. grne Eichel 70 Ringe KKA
# 82   KKA 1. grne Eichel 70 Ringe KKA
# 84   KKA 1. grne Eichel 70 Ringe KKA
# 86   KKA 1. grne Eichel 70 Ringe KKA
# 88   KKA 1. grne Eichel 70 Ringe KKA
# 91   KKA 1. grne Eichel 70 Ringe KKA
# 92   KKA 1. grne Eichel 70 Ringe KKA
# 94   KKA 1. grne Eichel 70 Ringe KKA
# 96   KKA 1. grne Eichel 70 Ringe KKA
# 186                KKA OldiPokal KKA
# 188                KKA OldiPokal KKA
# 189                KKA OldiPokal KKA
# 190              KKA Vogelteiler KKA

# %%
teilertest = oldies_full
teilertest['TotalDistance'] = abs(oldies_full['Distance'] - 2022)
teilertest.sort_values(['TotalDistance'], ascending=True, inplace=True)

# %%
teilertest.head()
# Out:
#                 ShotDateTime Competition DiscType  Distance  Count  FullValue  \
# 196  2022-08-22 20:01:37.000        None      KKA    2022.2      1          8
# 49   2022-07-12 18:52:56.000        None      KKA    2028.4      2          8
# 189  2022-08-22 19:56:22.000        None      KKA    2014.0      2          8
# 96   2022-08-15 20:07:00.000        None      KKA    2034.7      9          8
# 168  2022-08-22 19:44:37.000        None      KKA    2007.4      0          8
#
#      DecValue  IsHot Shooter.Firstname Shooter.Lastname  Shooter.Birthyear  \
# 196       8.4   True             Bernd       008 Boysen               1949
# 49        8.4   True            Regina     306- Neumann               1956
# 189       8.4   True            Rudolf       248 Rieger               1972
# 96        8.4   True            Rudolf       248 Rieger               1972
# 168       8.4   True              Lars      185 Balhorn               1980
#
#     Shooter.Identification Shooter.Team Shooter.Club  \
# 196                      8         None         None
# 49                     306         None         None
# 189                    248         None         None
# 96                     248         None         None
# 168                    185         None         None
#
#               MenuItem.MenuPointName  TotalDistance
# 196                KKA OldiPokal KKA            0.2
# 49   KKA 1. grne Eichel 70 Ringe KKA            6.4
# 189                KKA OldiPokal KKA            8.0
# 96   KKA 1. grne Eichel 70 Ringe KKA           12.7
# 168              KKA Vogelteiler KKA           14.6

# %%
oldies_full[oldies_full['Shooter.Firstname'] == 'Kai-Frederik']
# Out:
#                 ShotDateTime Competition DiscType  Distance  Count  FullValue  \
# 237  2022-08-22 20:55:22.000        None      KKA    2360.9      1          8
# 239  2022-08-22 20:56:17.000        None      KKA    1507.4      0          9
# 236  2022-08-22 20:54:47.000        None      KKA    3757.0      0          6
# 238  2022-08-22 20:55:40.000        None      KKA    6371.4      2          3
#
#      DecValue  IsHot Shooter.Firstname Shooter.Lastname  Shooter.Birthyear  \
# 237       8.0   True      Kai-Frederik    311 Schilling               1988
# 239       9.1   True      Kai-Frederik    311 Schilling               1988
# 236       6.3   True      Kai-Frederik    311 Schilling               1988
# 238       3.0   True      Kai-Frederik    311 Schilling               1988
#
#     Shooter.Identification Shooter.Team Shooter.Club MenuItem.MenuPointName  \
# 237                    312         None         None      KKA OldiPokal KKA
# 239                    312         None         None    KKA Vogelteiler KKA
# 236                    312         None         None      KKA OldiPokal KKA
# 238                    312         None         None      KKA OldiPokal KKA
#
#      TotalDistance
# 237          338.9
# 239          514.6
# 236         1735.0
# 238         4349.4

# %%
oldies_full[oldies_full['Shooter.Firstname'] == 'Kai-Frederik']['DecValue'].nlargest(2)
# Out:
# 239    9.1
# 237    8.0
# Name: DecValue, dtype: float64

# %%
oldies_full[oldies_full['Shooter.Firstname'] == 'Kai-Frederik']['DecValue'].nlargest(2).sum()
# Out:
# 17.1

# %%
oldies_full[oldies_full['Shooter.Firstname'] == 'Kai-Frederik']['Distance'].nsmallest(2).sum()
# Out:
# 3868.3

# %%
oldies_full[oldies_full['Shooter.Firstname'] == 'Kai-Frederik']['Distance'].idxmin()
# Out:
# 239
